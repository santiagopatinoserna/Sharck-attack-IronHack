# %% [markdown]
# # ANALISIS DE ATAQUE DE TIBURONES PARA MAPFRE SEGUROS

# %% [markdown]
# ## Importación de Dataframe y hoja de funciones

# %%
import pandas as pd

url= "https://www.sharkattackfile.net/spreadsheets/GSAF5.xls"

df1= pd.read_excel(url)

import funciones as f

# %% [markdown]
# ### Creación de copia
# #### Para resguardar los datos

# %%
df_original=df1.copy()
df=df_original

# %% [markdown]
# ### Limpieza de Dataframe
# ##### Se llama a la hoja de funciones previamente importada, la cual realiza todas las funciones de limpieza.

# %%
df=f.limpiar_dataframe(df)

# %% [markdown]
# ### Gráficos
#
# ##### Uso de la función para la generación de los gráficos

# %%
f.creacion_de_graficos(df)
